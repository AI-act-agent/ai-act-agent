# %%
"""
01_rag_pipeline.py
V0 (순수 LLM) → V1 (RAG) → V2 (조문 참조 그래프) 파이프라인
- 임베딩: sentence-transformers (로컬)
- 채팅:   Groq API (무료, llama-3.3-70b)
"""

import os
import json
import numpy as np
from pathlib import Path
from groq import Groq
from sentence_transformers import SentenceTransformer

# ──────────────────────────────────────────
# 설정
# ──────────────────────────────────────────
GROQ_API_KEY = ""   # console.groq.com에서 발급
client     = Groq(api_key=GROQ_API_KEY)
CHAT_MODEL = "llama-3.3-70b-versatile"
TOP_K      = 5
REF_DEPTH  = 1

CHUNKS_FILE = Path("data/chunks.json")
DB_FILE     = Path("data/vectordb.json")

print("임베딩 모델 로딩 중...")
_embedder = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")
print("임베딩 모델 로딩 완료")


# ──────────────────────────────────────────
# 임베딩 (로컬)
# ──────────────────────────────────────────
def embed(texts: list) -> list:
    return _embedder.encode(texts, normalize_embeddings=True).tolist()

def embed_query(text: str) -> list:
    return _embedder.encode(text, normalize_embeddings=True).tolist()


# ──────────────────────────────────────────
# 벡터 DB
# ──────────────────────────────────────────
def cosine_sim(a, b):
    a, b = np.array(a), np.array(b)
    return float(np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b) + 1e-10))


class SimpleVectorDB:
    def __init__(self):
        self.ids      = []
        self.texts    = []
        self.vectors  = []
        self.metadata = []

    def add(self, chunk_id, text, vector, meta):
        self.ids.append(chunk_id)
        self.texts.append(text)
        self.vectors.append(vector)
        self.metadata.append(meta)

    def search(self, query_vector, top_k=TOP_K):
        sims    = [cosine_sim(query_vector, v) for v in self.vectors]
        top_idx = sorted(range(len(sims)), key=lambda i: sims[i], reverse=True)[:top_k]
        return [{**self.metadata[i], "score": sims[i]} for i in top_idx]

    def get_by_id(self, chunk_id):
        for i, cid in enumerate(self.ids):
            if chunk_id == cid or cid.startswith(chunk_id):
                return self.metadata[i]
        return None

    def save(self, path):
        path.write_text(json.dumps({
            "ids": self.ids, "texts": self.texts,
            "vectors": self.vectors, "metadata": self.metadata,
        }, ensure_ascii=False), encoding="utf-8")

    def load(self, path):
        data      = json.loads(path.read_text(encoding="utf-8"))
        self.ids      = data["ids"]
        self.texts    = data["texts"]
        self.vectors  = data["vectors"]
        self.metadata = data["metadata"]


# ──────────────────────────────────────────
# 인덱스 빌드
# ──────────────────────────────────────────
def build_index(chunks_file: Path, db_file: Path):
    data      = json.loads(chunks_file.read_text(encoding="utf-8"))
    chunks    = data["chunks"]
    ref_graph = data["ref_graph"]

    if db_file.exists():
        print("기존 벡터 DB 로드 중...")
        db = SimpleVectorDB()
        db.load(db_file)
        return db, ref_graph

    print(f"{len(chunks)}개 chunk 임베딩 중...")
    db    = SimpleVectorDB()
    BATCH = 100
    for i in range(0, len(chunks), BATCH):
        batch = chunks[i:i+BATCH]
        texts = [f"{c['article_num']} {c.get('article_title','')} {c['text']}" for c in batch]
        vecs  = embed(texts)
        for chunk, vec in zip(batch, vecs):
            db.add(chunk["id"], chunk["text"], vec, chunk)
        print(f"  {min(i+BATCH, len(chunks))}/{len(chunks)}")

    db.save(db_file)
    print(f"벡터 DB 저장: {db_file}")
    return db, ref_graph


# ──────────────────────────────────────────
# 조문 포매터
# ──────────────────────────────────────────
def format_chunks(chunks: list) -> str:
    lines = []
    for c in chunks:
        title = f"({c.get('article_title','')})" if c.get("article_title") else ""
        lines.append(f"[{c['id']}]{title} {c['text']}")
    return "\n\n".join(lines)


# ──────────────────────────────────────────
# LLM 채팅 헬퍼
# ──────────────────────────────────────────
def chat(system_prompt: str, user_prompt: str) -> str:
    resp = client.chat.completions.create(
        model=CHAT_MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user",   "content": user_prompt},
        ],
    )
    return resp.choices[0].message.content


# ──────────────────────────────────────────
# V0: 순수 LLM (Baseline)
# ──────────────────────────────────────────
def v0_baseline(question: str) -> dict:
    answer = chat(
        system_prompt=(
            "당신은 한국 AI기본법 전문가입니다. "
            "사전 학습 지식으로만 답변하고, 조문을 인용할 때는 정확한 조문 번호를 명시하세요."
        ),
        user_prompt=question,
    )
    return {"version": "V0", "answer": answer, "retrieved_chunks": []}


# ──────────────────────────────────────────
# V1: 기본 RAG
# ──────────────────────────────────────────
def v1_rag(question: str, db: SimpleVectorDB) -> dict:
    q_vec   = embed_query(question)
    results = db.search(q_vec, top_k=TOP_K)
    context = format_chunks(results)

    answer = chat(
        system_prompt="""당신은 AI기본법 컴플라이언스 QA 에이전트입니다.
규칙:
1. 반드시 아래 [관련 조문]만을 근거로 답변하세요.
2. 각 주장마다 조문 번호를 [제○조 제○항] 형식으로 인용하세요.
3. 조문에 근거가 없으면 "현재 제공된 조문에서 확인할 수 없습니다."라고 명시하세요.
4. 법률 자문이 아닌 문서 기반 QA임을 명심하세요.""",
        user_prompt=f"[관련 조문]\n{context}\n\n[질문]\n{question}",
    )
    return {
        "version":          "V1",
        "answer":           answer,
        "retrieved_chunks": [c["id"] for c in results],
        "scores":           [round(c["score"], 4) for c in results],
    }


# ──────────────────────────────────────────
# V2: RAG + 조문 참조 그래프 탐색
# ──────────────────────────────────────────
def v2_rag_with_refs(question: str, db: SimpleVectorDB, ref_graph: dict, depth: int = REF_DEPTH) -> dict:
    q_vec   = embed_query(question)
    initial = db.search(q_vec, top_k=TOP_K)

    expanded_ids = set(c["id"] for c in initial)
    frontier     = list(expanded_ids)

    for _ in range(depth):
        next_frontier = []
        for cid in frontier:
            chunk_meta = db.get_by_id(cid)
            if chunk_meta:
                for ref in chunk_meta.get("refs", []):
                    ref_chunk = db.get_by_id(ref)
                    if ref_chunk and ref_chunk["id"] not in expanded_ids:
                        expanded_ids.add(ref_chunk["id"])
                        initial.append(ref_chunk)
                        next_frontier.append(ref_chunk["id"])
        frontier = next_frontier

    context = format_chunks(initial)
    answer  = chat(
        system_prompt="""당신은 AI기본법 컴플라이언스 QA 에이전트입니다.
규칙:
1. 반드시 아래 [관련 조문]만을 근거로 답변하세요.
2. 각 주장마다 조문 번호를 [제○조 제○항] 형식으로 인용하세요.
3. 조문에 근거가 없으면 "현재 제공된 조문에서 확인할 수 없습니다."라고 명시하세요.""",
        user_prompt=f"[관련 조문]\n{context}\n\n[질문]\n{question}",
    )
    return {
        "version":          "V2",
        "answer":           answer,
        "retrieved_chunks": list(expanded_ids),
        "initial_chunks":   [c["id"] for c in initial[:TOP_K]],
        "expanded_chunks":  list(expanded_ids - set(c["id"] for c in initial[:TOP_K])),
    }


# ──────────────────────────────────────────
# 실행 예시
# ──────────────────────────────────────────
if __name__ == "__main__":
    from datetime import datetime

    RESULTS_DIR = Path("results")
    RESULTS_DIR.mkdir(exist_ok=True)

    db, ref_graph = build_index(CHUNKS_FILE, DB_FILE)

    test_questions = [
        "저희는 AI로 채용 서류를 1차 스크리닝하는데, 최종 합격은 사람이 결정합니다. 고영향 AI인가요?",
        "AI 서비스 출시 전에 반드시 해야 하는 의무 고지 사항은 무엇인가요?",
        "AI기본법에서 '사업자'의 정의는 무엇인가요?",
        "AI 생성 이미지에 워터마크를 반드시 붙여야 하나요?",
    ]

    all_results = []

    for q in test_questions:
        print(f"\n{'='*60}")
        print(f"[질문] {q}")

        r0 = v0_baseline(q)
        print(f"\n[V0 - Baseline]\n{r0['answer'][:300]}...")

        r1 = v1_rag(q, db)
        print(f"\n[V1 - RAG] 검색된 조문: {r1['retrieved_chunks']}")
        print(r1['answer'][:300], "...")

        r2 = v2_rag_with_refs(q, db, ref_graph)
        print(f"\n[V2 - RAG+Graph] 확장 조문: {r2['expanded_chunks']}")
        print(r2['answer'][:300], "...")

        all_results.append({
            "question": q,
            "V0": r0,
            "V1": r1,
            "V2": r2,
        })

    # 결과 저장
    ts      = datetime.now().strftime("%m%d_%H%M")
    out     = RESULTS_DIR / f"results_{ts}.json"
    out.write_text(json.dumps(all_results, ensure_ascii=False, indent=2), encoding="utf-8")
    print(f"\n결과 저장 완료: {out}")
# Out:
# 임베딩 모델 로딩 중...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# 임베딩 모델 로딩 완료
# 기존 벡터 DB 로드 중...
#
# ============================================================
# [질문] 저희는 AI로 채용 서류를 1차 스크리닝하는데, 최종 합격은 사람이 결정합니다. 고영향 AI인가요?
#
# [V0 - Baseline]
# 한국 AI기본법에 따르면, AI시스템이 사람의 의사決定을 대신하거나 사람의 의사決定에 직접영향을 미치는 경우를 고영향 AI로 정의했습니다(제2조 제1항 제5호).
#
# 그러나, 서류 접수부터 최종 合格자 결정까지 전 과정에 걸쳐 AI시스템이 활용된다 하더라도, 최종 合格자 결정에 대한 권한을 사람에게 부여하였다면, 고영향 AI에 해당하지 않습니다.
#
# 따라서, 최종 합격은 사람이 결정하는 경우라면, 고영향 AI로 간주되지 않을 가능성이 있습니다. 다만, 구체적인 경우에 따라 달라질 수 있으므로, 법률 전문가의咨询을 받는 것이 좋습니다...
#
# [V1 - RAG] 검색된 조문: ['제10조제2항음호', '제35조', '제28조제4항다호', '제10조제2항임호', '제33조제4항']
# [제28조제4항다호] 및 [제33조제4항]의 내용을 근거로 본다면, 채용 서류 1차 스크리닝에서 AI를 사용하는 경우, 이는 고영향 인공지능 해당 여부의 재확인에 참고가 될 수 있는 상황입니다. 하지만, 최종 합격은 사람이 결정한다고 하므로, 직접적인 결정은 사람이 하는 것이므로, 고영향 AI의 여부는 추가적인 확인이 필요합니다. [현재 제공된 조문에서 확인할 수 없습니다.] ...
#
# [V2 - RAG+Graph] 확장 조문: ['제25조']
# [제10조제2항임호]에 따르면, 고영향 인공지능의 확인 여부는 과학기술정보통신부장관이 결정합니다. [제28조제4항다호]에 따르면, 고영향 인공지능 해당 여부의 확인은 과학기술정보통신부장관의 회신 결과나 그 밖에 참고가 될 수 있는 서류를 참고하여 결정할 수 있습니다.
#
# 그러나 [제33조제4항]에 따르면, 고영향 인공지능의 확인 절차 등에 관하여 필요한 사항은 대통령령으로 정하므로, 현재 제공된 조문에서 확인할 수 없습니다. ...
#
# ============================================================
# [질문] AI 서비스 출시 전에 반드시 해야 하는 의무 고지 사항은 무엇인가요?
#
# [V0 - Baseline]
# 한국의 AI기본법에서는 AI 서비스 제공자가 서비스를 출시하기 전에 반드시 해야 하는 의무 고지 사항을 규정하고 있습니다. AI 서비스 제공자는 「한국형 AI 기본법」 제23조에 따라 서비스 출시 전 AI의 목적, 기능, 한계 등을 이용자에게 명확히 고지해야 합니다....
#
# [V1 - RAG] 검색된 조문: ['제16조', '제22조의2', '제22조의2제2항다호', '제32조제2항', '제22조의2']
# 현재 제공된 조문에서 확인할 수 없습니다. [제32조제2항]에 따르면 인공지능사업자는 인공지능 안전성 확보 의무와 관련된 사항의 이행 결과를 과학기술정보통신부장관에게 제출해야 하나, AI 서비스 출시 전에 반드시 해야 하는 의무 고지 사항에 대한 내용은 제공된 조문에 없습니다. ...
#
# [V2 - RAG+Graph] 확장 조문: []
# 현재 제공된 조문에서 확인할 수 없습니다. ...
#
# ============================================================
# [질문] AI기본법에서 '사업자'의 정의는 무엇인가요?
#
# [V0 - Baseline]
# AI기본법 제2조 제1호에서는 '사업자'를 다음과 같이 정의하고 있습니다.
#
# 사업자: 이 법에서 정하는 목적business 사업을 영위하는 자로서 대통령령으로 정하는 사람을 말한다....
#
# [V1 - RAG] 검색된 조문: ['제41조제2항', '제35조', '제2조', '제28조제1항', '제36조']
# 현재 제공된 조문에서 확인할 수 없습니다. [제2조](정의)에서는 법에서 사용하는 용어의 뜻을 정의하고 있지만, 여기에는 '사업자'의 정의가 포함되지 않습니다. 따라서 사업자의 정의는 제공된 관련 조문에서 확인할 수 없습니다. ...
#
# [V2 - RAG+Graph] 확장 조문: ['제39조제2항다호']
# 현재 제공된 조문에서 확인할 수 없습니다. [제2조](정의)에서 이 법에서 사용하는 용어의 뜻은 기술되어 있으나, '사업자'의 정의는 명시되어 있지 않습니다. ...
#
# ============================================================
# [질문] AI 생성 이미지에 워터마크를 반드시 붙여야 하나요?
#
# [V0 - Baseline]
# 한국 AI기본법 제23조(인공지능 생성 콘텐츠의 표시)에서 규정하고 있는 인공지능 생성 콘텐츠의 표시義무는 원칙적으로 선택义무이며, 필수는 아닙니다. 다만, 필수적으로 표시하여야 하는 경우도 있습니다. 따라서, AI 생성 이미지에 워터마크를 반드시 붙여야 하는지 여부는 경우에 따라 다를 수 있습니다....
#
# [V1 - RAG] 검색된 조문: ['제23조', '제23조', '제10조제2항다호', '제261조', '제2조']
# [제23조]에 따르면, AI 생성물에 대한 표시 방법은 사람이나 기계가 인식할 수 있는 방법이 있습니다.
#  사람이 인식할 수 있는 방법으로는 화면 영역 일부에 로고 등을 표출하거나, 영상 시작 부분에 AI 생성 사실을 안내하는 방법 등이 있으며,
#  기계가 판독할 수 있는 방법으로는 디지털 워터마킹, 메타데이터 등을 활용한 비가시적인 방법이 있습니다.
#  또한, 실제와 구분하기 어려운 생성물(딥페이크)의 경우에는 AI로 생성된 재생구간 전체에 로고 표출 등으로 AI 생성 사실을 표시해야 합니다.
#
# 그러나 모든 AI 생성 이미지에 워터 ...
#
# [V2 - RAG+Graph] 확장 조문: []
# [제23조]에 따르면, AI 생성물에 대한 표시 방법은 2가지가 있습니다. 하나는 사람이 인식할 수 있는 방법(화면 영역 일부에 로고 등을 표출하거나, 영상 시작 부분에 AI 생성 사실을 안내하는 방법 등)이고, 다른 하나는 기계가 판독할 수 있는 방법(디지털 워터마킹, 메타데이터 등을 활용한 비가시적인 방법)입니다. 실제와 구분하기 어려운 생성물(딥페이크)의 경우, 명확하게 인식할 수 있는 방법으로써 사람이 인식할 수 있는 방법만을 적용하여야 하며, AI로 생성된 재생구간 전체에 로고 표출 등으로 AI 생성 사실을 표시하여야 한다 ...
#
# 결과 저장 완료: results/results_0720_2306.json
